# %%
import pandas as pd
import numpy as np

# %%
orders  = pd.read_csv(r'C:\Users\Rathang Rajpal\Desktop\sem 6\Intern_Xebia\Customer Segmentation\codes\instakart data\orders.csv\orders.csv')

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
department = pd.read_csv(r'C:\Users\Rathang Rajpal\Desktop\sem 6\Intern_Xebia\Customer Segmentation\codes\instakart data\departments.csv\departments.csv')
aisles = pd.read_csv(r'C:\Users\Rathang Rajpal\Desktop\sem 6\Intern_Xebia\Customer Segmentation\codes\instakart data\aisles.csv\aisles.csv')

# %%
aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
department.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
products = pd.read_csv(r'C:\Users\Rathang Rajpal\Desktop\sem 6\Intern_Xebia\Customer Segmentation\codes\instakart data\products.csv\products.csv')
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
prod_order = pd.read_csv(r'C:\Users\Rathang Rajpal\Desktop\sem 6\Intern_Xebia\Customer Segmentation\codes\instakart data\order_products__train.csv\order_products__train.csv')

# %%
prod_order.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
prod_order_p = pd.read_csv(r'C:\Users\Rathang Rajpal\Desktop\sem 6\Intern_Xebia\Customer Segmentation\codes\instakart data\order_products__prior.csv\order_products__prior.csv')

# %%
prod_order_p.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
prod_dept = products.merge(department,how = 'left',on = 'department_id')
prod_dept.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id department
# 0             19     snacks
# 1             13     pantry
# 2              7  beverages
# 3              1     frozen
# 4             13     pantry

# %%
product_dept = prod_dept.set_index('product_id').drop(['product_name','aisle_id','department_id'],axis = 1)

# %%
product_dept.head()
# Out:
#            department
# product_id
# 1              snacks
# 2              pantry
# 3           beverages
# 4              frozen
# 5              pantry

# %%
d = {}
for i in product_dept.index:
    d[i] = product_dept['department'][i]

# %%
d[29429]
# Out:
# 'breakfast'

# %%
customer_orders = pd.merge(orders,prod_order,on = 'order_id')

# %%
customer_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1    train            11          4                  8
# 1   1187899        1    train            11          4                  8
# 2   1187899        1    train            11          4                  8
# 3   1187899        1    train            11          4                  8
# 4   1187899        1    train            11          4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                    14.0         196                  1          1
# 1                    14.0       25133                  2          1
# 2                    14.0       38928                  3          1
# 3                    14.0       26405                  4          1
# 4                    14.0       39657                  5          1

# %%
custgoods = customer_orders.groupby('user_id')['product_id'].apply(list).reset_index()
custgood = custgoods.set_index('user_id')

# %%
custgoods['product_id'].values[0]
# Out:
# [196, 25133, 38928, 26405, 39657, 10258, 13032, 26088, 27845, 49235, 46149]

# %%
custgood.tail()
# Out:
#                                                 product_id
# user_id
# 206199   [29429, 8898, 6128, 6701, 38855, 38341, 43821,...
# 206200   [22828, 13176, 39190, 34243, 8174, 27451, 1559...
# 206203   [15693, 37188, 21469, 41007, 2482, 14050, 2638...
# 206205   [27845, 21137, 28745, 22035, 24852, 46886, 314...
# 206209   [6846, 9405, 24852, 40603, 15655, 42606, 37966...

# %%
l = custgood['product_id'][206199]

# %%
user_d = {}
for ind in custgood.index:
    l = [d[k] for k in custgood['product_id'][ind]]
    user_d[ind] = l

# %%
#dictionary contatining the departments from which a particular customer had bought goods from 
user_d
# Out:
# {1: ['beverages',
#   'dairy eggs',
#   'dairy eggs',
#   'household',
#   'snacks',
#   'snacks',
#   'breakfast',
#   'snacks',
#   'dairy eggs',
#   'dairy eggs',
#   'beverages'],
#  2: ['deli',
#   'frozen',
#   'snacks',
#   'snacks',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'snacks',
#   'deli',
#   'personal care',
#   'deli',
#   'frozen',
#   'frozen',
#   'frozen',
#   'frozen',
#   'frozen',
#   'frozen',
#   'frozen',
#   'canned goods',
#   'frozen',
#   'frozen',
#   'frozen',
#   'snacks',
#   'snacks',
#   'canned goods',
#   'canned goods'],
#  5: ['pantry',
#   'produce',
#   'dairy eggs',
#   'international',
#   'household',
#   'produce',
#   'international',
#   'produce',
#   'produce'],
#  7: ['beverages',
#   'beverages',
#   'beverages',
#   'meat seafood',
#   'beverages',
#   'dairy eggs',
#   'beverages',
#   'pantry',
#   'produce'],
#  8: ['produce',
#   'deli',
#   'pantry',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'bakery',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'canned goods',
#   'produce'],
#  9: ['snacks',
#   'beverages',
#   'deli',
#   'beverages',
#   'produce',
#   'deli',
#   'bakery',
#   'bakery',
#   'bakery',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'breakfast',
#   'breakfast'],
#  10: ['meat seafood', 'frozen', 'bakery', 'pantry'],
#  13: ['bakery', 'dairy eggs', 'dairy eggs', 'personal care', 'dairy eggs'],
#  14: ['pantry',
#   'other',
#   'produce',
#   'bakery',
#   'bakery',
#   'pantry',
#   'pantry',
#   'pantry',
#   'frozen',
#   'alcohol',
#   'bakery'],
#  17: ['dairy eggs',
#   'household',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'household'],
#  18: ['beverages',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'meat seafood',
#   'produce',
#   'canned goods',
#   'personal care',
#   'meat seafood'],
#  21: ['snacks', 'snacks', 'beverages', 'beverages', 'beverages', 'beverages'],
#  23: ['produce',
#   'dairy eggs',
#   'dairy eggs',
#   'household',
#   'canned goods',
#   'canned goods',
#   'canned goods',
#   'canned goods',
#   'dairy eggs',
#   'dairy eggs',
#   'household',
#   'produce'],
#  24: ['beverages'],
#  27: ['beverages',
#   'beverages',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs'],
#  29: ['snacks',
#   'frozen',
#   'snacks',
#   'bakery',
#   'dairy eggs',
#   'frozen',
#   'pantry',
#   'snacks',
#   'household',
#   'beverages',
#   'snacks',
#   'pantry',
#   'pantry',
#   'deli',
#   'pantry',
#   'snacks',
#   'beverages'],
#  30: ['beverages'],
#  34: ['dairy eggs', 'produce', 'dry goods pasta', 'dairy eggs', 'dairy eggs'],
#  37: ['produce',
#   'dairy eggs',
#   'snacks',
#   'canned goods',
#   'produce',
#   'frozen',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'pantry',
#   'produce',
#   'produce'],
#  38: ['pantry',
#   'dry goods pasta',
#   'dairy eggs',
#   'dairy eggs',
#   'household',
#   'frozen',
#   'dry goods pasta',
#   'dairy eggs',
#   'frozen',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'snacks',
#   'household',
#   'dairy eggs',
#   'personal care',
#   'produce',
#   'produce',
#   'produce'],
#  41: ['meat seafood',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'meat seafood',
#   'snacks',
#   'deli',
#   'produce',
#   'produce',
#   'canned goods',
#   'canned goods',
#   'international',
#   'snacks',
#   'dairy eggs'],
#  42: ['snacks',
#   'frozen',
#   'bakery',
#   'produce',
#   'frozen',
#   'snacks',
#   'beverages'],
#  43: ['produce',
#   'produce',
#   'household',
#   'deli',
#   'breakfast',
#   'dairy eggs',
#   'deli',
#   'dairy eggs',
#   'deli',
#   'deli',
#   'pantry',
#   'pantry',
#   'dry goods pasta',
#   'international',
#   'pantry',
#   'frozen',
#   'produce',
#   'frozen',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dry goods pasta',
#   'dairy eggs',
#   'dairy eggs',
#   'pantry',
#   'produce',
#   'dairy eggs',
#   'meat seafood',
#   'dry goods pasta',
#   'pantry',
#   'frozen',
#   'frozen'],
#  44: ['pantry',
#   'meat seafood',
#   'bakery',
#   'meat seafood',
#   'produce',
#   'personal care'],
#  46: ['produce',
#   'snacks',
#   'dry goods pasta',
#   'produce',
#   'meat seafood',
#   'produce'],
#  47: ['personal care',
#   'personal care',
#   'personal care',
#   'canned goods',
#   'frozen',
#   'frozen'],
#  48: ['snacks',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dry goods pasta',
#   'dry goods pasta',
#   'produce',
#   'international',
#   'meat seafood',
#   'produce'],
#  49: ['bakery', 'snacks', 'pantry', 'pets', 'frozen', 'frozen'],
#  50: ['beverages', 'produce', 'produce', 'produce', 'produce', 'dairy eggs'],
#  52: ['beverages',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'snacks',
#   'produce',
#   'produce',
#   'pantry',
#   'snacks',
#   'produce'],
#  53: ['beverages',
#   'pantry',
#   'dairy eggs',
#   'pets',
#   'beverages',
#   'household',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'produce',
#   'canned goods',
#   'produce'],
#  55: ['snacks',
#   'produce',
#   'beverages',
#   'snacks',
#   'snacks',
#   'dairy eggs',
#   'produce',
#   'deli',
#   'bakery',
#   'dairy eggs',
#   'frozen',
#   'frozen',
#   'snacks'],
#  56: ['produce',
#   'snacks',
#   'produce',
#   'produce',
#   'snacks',
#   'produce',
#   'produce',
#   'produce',
#   'meat seafood'],
#  59: ['produce',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'produce',
#   'babies',
#   'breakfast',
#   'snacks',
#   'snacks',
#   'produce',
#   'dairy eggs',
#   'deli',
#   'pantry',
#   'pantry',
#   'babies',
#   'babies',
#   'meat seafood',
#   'pantry',
#   'dairy eggs',
#   'produce',
#   'dairy eggs'],
#  62: ['dairy eggs',
#   'frozen',
#   'produce',
#   'dry goods pasta',
#   'frozen',
#   'produce',
#   'meat seafood',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce'],
#  63: ['bakery',
#   'dairy eggs',
#   'meat seafood',
#   'dairy eggs',
#   'bakery',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'dry goods pasta',
#   'dairy eggs',
#   'frozen'],
#  64: ['produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'beverages',
#   'dairy eggs',
#   'frozen',
#   'beverages',
#   'bulk',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'dry goods pasta'],
#  65: ['bulk',
#   'bakery',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'snacks',
#   'produce',
#   'frozen'],
#  66: ['breakfast',
#   'dairy eggs',
#   'pantry',
#   'produce',
#   'produce',
#   'pantry',
#   'pantry'],
#  67: ['beverages', 'produce', 'produce'],
#  70: ['produce'],
#  71: ['dairy eggs',
#   'bakery',
#   'dairy eggs',
#   'produce',
#   'canned goods',
#   'dairy eggs',
#   'dairy eggs',
#   'dry goods pasta',
#   'meat seafood',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'household',
#   'bakery',
#   'household',
#   'canned goods',
#   'pantry',
#   'pets',
#   'snacks',
#   'pantry',
#   'pantry',
#   'pantry',
#   'snacks',
#   'snacks',
#   'dairy eggs'],
#  72: ['dairy eggs', 'deli'],
#  74: ['breakfast', 'produce', 'produce', 'canned goods', 'dry goods pasta'],
#  76: ['beverages', 'household', 'household'],
#  78: ['beverages', 'produce', 'dairy eggs'],
#  79: ['dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'bakery',
#   'dairy eggs'],
#  80: ['dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'frozen',
#   'snacks',
#   'breakfast',
#   'dairy eggs',
#   'pantry',
#   'snacks',
#   'dairy eggs'],
#  81: ['produce', 'produce', 'produce'],
#  82: ['dairy eggs',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'snacks',
#   'snacks'],
#  83: ['dry goods pasta', 'snacks', 'bakery'],
#  84: ['beverages',
#   'produce',
#   'produce',
#   'snacks',
#   'produce',
#   'produce',
#   'produce',
#   'pantry',
#   'produce',
#   'produce',
#   'snacks',
#   'snacks'],
#  86: ['produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'canned goods',
#   'canned goods',
#   'produce',
#   'international',
#   'produce',
#   'frozen',
#   'produce',
#   'produce',
#   'produce'],
#  87: ['beverages',
#   'dairy eggs',
#   'bakery',
#   'produce',
#   'produce',
#   'produce',
#   'frozen'],
#  88: ['pets', 'dairy eggs', 'dairy eggs'],
#  89: ['dairy eggs',
#   'dairy eggs',
#   'canned goods',
#   'produce',
#   'deli',
#   'produce',
#   'canned goods',
#   'deli',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'snacks',
#   'pantry'],
#  90: ['snacks', 'breakfast', 'breakfast', 'breakfast', 'snacks'],
#  91: ['produce',
#   'produce',
#   'snacks',
#   'dairy eggs',
#   'bakery',
#   'dairy eggs',
#   'dairy eggs',
#   'frozen',
#   'dairy eggs',
#   'breakfast',
#   'bakery',
#   'dairy eggs',
#   'dairy eggs',
#   'frozen',
#   'canned goods',
#   'snacks',
#   'bakery',
#   'international',
#   'canned goods',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'canned goods',
#   'produce',
#   'pantry',
#   'pantry',
#   'frozen',
#   'bakery',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'pantry',
#   'produce'],
#  93: ['snacks',
#   'personal care',
#   'beverages',
#   'beverages',
#   'produce',
#   'produce',
#   'beverages',
#   'beverages'],
#  95: ['dairy eggs',
#   'dairy eggs',
#   'frozen',
#   'frozen',
#   'international',
#   'produce',
#   'dry goods pasta',
#   'produce',
#   'produce',
#   'snacks',
#   'pantry',
#   'dairy eggs',
#   'canned goods',
#   'dairy eggs',
#   'canned goods',
#   'pantry',
#   'deli',
#   'breakfast'],
#  96: ['bakery',
#   'frozen',
#   'beverages',
#   'produce',
#   'produce',
#   'frozen',
#   'frozen',
#   'frozen',
#   'dry goods pasta',
#   'personal care',
#   'snacks'],
#  97: ['beverages'],
#  99: ['produce',
#   'produce',
#   'deli',
#   'deli',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'meat seafood',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'beverages',
#   'beverages'],
#  102: ['produce',
#   'produce',
#   'dairy eggs',
#   'deli',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'pantry',
#   'produce',
#   'produce',
#   'dry goods pasta',
#   'pantry',
#   'snacks'],
#  103: ['dairy eggs'],
#  104: ['deli',
#   'deli',
#   'deli',
#   'deli',
#   'deli',
#   'deli',
#   'deli',
#   'deli',
#   'deli',
#   'missing',
#   'deli'],
#  105: ['produce', 'beverages', 'dairy eggs', 'pantry'],
#  106: ['household',
#   'beverages',
#   'beverages',
#   'beverages',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'canned goods',
#   'canned goods',
#   'breakfast',
#   'snacks',
#   'snacks',
#   'bakery',
#   'bakery',
#   'household'],
#  108: ['produce',
#   'dairy eggs',
#   'dry goods pasta',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs'],
#  109: ['pets',
#   'produce',
#   'produce',
#   'bakery',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'canned goods',
#   'produce',
#   'canned goods',
#   'canned goods',
#   'produce',
#   'produce',
#   'canned goods',
#   'pantry',
#   'pantry',
#   'bakery'],
#  110: ['produce',
#   'deli',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'missing',
#   'dairy eggs',
#   'deli',
#   'produce',
#   'dairy eggs',
#   'produce'],
#  111: ['meat seafood',
#   'dairy eggs',
#   'snacks',
#   'produce',
#   'produce',
#   'snacks',
#   'dairy eggs',
#   'beverages',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dry goods pasta',
#   'deli',
#   'produce',
#   'bakery',
#   'dairy eggs',
#   'snacks',
#   'bakery',
#   'meat seafood',
#   'pantry',
#   'canned goods',
#   'dairy eggs',
#   'bakery',
#   'produce'],
#  112: ['dairy eggs'],
#  113: ['household', 'beverages'],
#  114: ['produce',
#   'produce',
#   'produce',
#   'produce',
#   'canned goods',
#   'meat seafood',
#   'dry goods pasta',
#   'produce',
#   'beverages',
#   'personal care',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'canned goods',
#   'produce',
#   'snacks',
#   'snacks',
#   'snacks'],
#  115: ['bakery',
#   'dairy eggs',
#   'canned goods',
#   'pantry',
#   'snacks',
#   'snacks',
#   'snacks',
#   'snacks',
#   'produce',
#   'frozen',
#   'meat seafood',
#   'frozen',
#   'deli'],
#  116: ['household', 'household', 'household', 'household', 'snacks'],
#  117: ['beverages',
#   'frozen',
#   'frozen',
#   'household',
#   'frozen',
#   'personal care',
#   'other',
#   'personal care',
#   'personal care'],
#  118: ['produce', 'dairy eggs', 'produce', 'produce'],
#  119: ['bakery',
#   'dairy eggs',
#   'snacks',
#   'deli',
#   'produce',
#   'beverages',
#   'deli',
#   'pantry',
#   'frozen',
#   'pantry',
#   'produce',
#   'breakfast',
#   'bakery',
#   'meat seafood',
#   'meat seafood'],
#  120: ['breakfast'],
#  121: ['produce', 'produce', 'dairy eggs', 'produce', 'produce'],
#  123: ['snacks',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'produce',
#   'produce',
#   'pantry',
#   'snacks',
#   'dairy eggs',
#   'international',
#   'beverages'],
#  124: ['produce',
#   'produce',
#   'canned goods',
#   'dry goods pasta',
#   'dry goods pasta',
#   'meat seafood',
#   'dry goods pasta',
#   'produce',
#   'produce'],
#  125: ['bakery',
#   'alcohol',
#   'beverages',
#   'produce',
#   'produce',
#   'deli',
#   'dairy eggs',
#   'snacks',
#   'snacks',
#   'bakery',
#   'snacks',
#   'dairy eggs',
#   'snacks',
#   'personal care',
#   'meat seafood',
#   'dairy eggs',
#   'dairy eggs',
#   'bakery',
#   'produce'],
#  128: ['dry goods pasta',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'pantry',
#   'other',
#   'babies',
#   'dairy eggs',
#   'dairy eggs'],
#  130: ['produce',
#   'produce',
#   'dairy eggs',
#   'beverages',
#   'deli',
#   'beverages',
#   'dairy eggs',
#   'dairy eggs',
#   'frozen'],
#  131: ['deli',
#   'snacks',
#   'dairy eggs',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'produce',
#   'produce'],
#  132: ['snacks',
#   'bakery',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs'],
#  135: ['dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'pantry',
#   'meat seafood',
#   'pantry',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs'],
#  138: ['dairy eggs'],
#  139: ['dairy eggs', 'snacks', 'produce'],
#  140: ['dairy eggs',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'deli',
#   'dairy eggs',
#   'snacks',
#   'canned goods',
#   'pantry',
#   'dry goods pasta',
#   'snacks',
#   'dairy eggs',
#   'pantry',
#   'dairy eggs',
#   'dairy eggs',
#   'deli',
#   'bulk',
#   'canned goods',
#   'canned goods',
#   'beverages',
#   'pantry',
#   'bakery'],
#  142: ['babies',
#   'dairy eggs',
#   'bakery',
#   'produce',
#   'beverages',
#   'dry goods pasta'],
#  143: ['produce',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'beverages',
#   'household',
#   'household',
#   'beverages',
#   'produce',
#   'dry goods pasta',
#   'dairy eggs',
#   'canned goods',
#   'missing',
#   'household'],
#  144: ['dairy eggs', 'deli', 'bakery'],
#  145: ['deli',
#   'bakery',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'breakfast',
#   'deli',
#   'produce'],
#  146: ['dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'pantry',
#   'deli',
#   'bakery',
#   'produce',
#   'meat seafood',
#   'beverages',
#   'pantry'],
#  147: ['snacks',
#   'deli',
#   'produce',
#   'snacks',
#   'snacks',
#   'breakfast',
#   'produce',
#   'alcohol',
#   'dairy eggs',
#   'pets',
#   'household',
#   'frozen',
#   'frozen'],
#  148: ['produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'household',
#   'beverages',
#   'beverages'],
#  150: ['bakery', 'snacks'],
#  155: ['dairy eggs', 'beverages', 'dairy eggs'],
#  157: ['beverages',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'dairy eggs',
#   'snacks',
#   'snacks',
#   'snacks'],
#  160: ['beverages',
#   'produce',
#   'beverages',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dry goods pasta',
#   'bakery',
#   'pantry',
#   'produce',
#   'pantry',
#   'beverages',
#   'meat seafood',
#   'pets',
#   'produce',
#   'produce',
#   'produce',
#   'produce'],
#  161: ['dairy eggs',
#   'dairy eggs',
#   'bakery',
#   'produce',
#   'produce',
#   'frozen',
#   'produce',
#   'frozen',
#   'pantry',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'frozen',
#   'frozen',
#   'frozen',
#   'dry goods pasta',
#   'produce'],
#  163: ['household',
#   'dairy eggs',
#   'other',
#   'pantry',
#   'meat seafood',
#   'produce',
#   'produce',
#   'snacks',
#   'snacks'],
#  164: ['beverages',
#   'produce',
#   'bakery',
#   'produce',
#   'beverages',
#   'dairy eggs',
#   'household',
#   'dairy eggs',
#   'international',
#   'pantry'],
#  167: ['personal care',
#   'pantry',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'frozen',
#   'frozen',
#   'snacks',
#   'dairy eggs',
#   'dairy eggs',
#   'deli',
#   'bakery',
#   'snacks',
#   'deli',
#   'produce',
#   'canned goods',
#   'canned goods',
#   'snacks'],
#  169: ['produce',
#   'produce',
#   'produce',
#   'bakery',
#   'bakery',
#   'deli',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce'],
#  171: ['beverages',
#   'meat seafood',
#   'snacks',
#   'dairy eggs',
#   'frozen',
#   'frozen',
#   'frozen',
#   'household',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'frozen',
#   'frozen'],
#  173: ['produce', 'frozen', 'snacks', 'snacks', 'beverages'],
#  174: ['personal care',
#   'beverages',
#   'personal care',
#   'frozen',
#   'meat seafood'],
#  175: ['produce'],
#  176: ['produce',
#   'produce',
#   'frozen',
#   'beverages',
#   'pantry',
#   'meat seafood',
#   'produce'],
#  178: ['frozen'],
#  179: ['dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce'],
#  183: ['breakfast',
#   'meat seafood',
#   'snacks',
#   'frozen',
#   'frozen',
#   'personal care',
#   'personal care',
#   'personal care',
#   'breakfast',
#   'dairy eggs',
#   'dairy eggs',
#   'pantry',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'deli',
#   'personal care',
#   'beverages',
#   'personal care',
#   'produce',
#   'canned goods',
#   'canned goods',
#   'dairy eggs',
#   'dairy eggs',
#   'pantry'],
#  184: ['dairy eggs',
#   'snacks',
#   'bakery',
#   'international',
#   'beverages',
#   'pantry',
#   'breakfast',
#   'produce',
#   'snacks',
#   'canned goods',
#   'dairy eggs',
#   'deli',
#   'deli',
#   'dairy eggs',
#   'dry goods pasta',
#   'dry goods pasta',
#   'produce',
#   'bakery',
#   'deli',
#   'snacks',
#   'deli',
#   'breakfast',
#   'produce',
#   'produce',
#   'pantry',
#   'beverages'],
#  185: ['bakery'],
#  187: ['beverages',
#   'dairy eggs',
#   'frozen',
#   'pets',
#   'pets',
#   'snacks',
#   'produce',
#   'frozen',
#   'household',
#   'alcohol',
#   'household'],
#  189: ['dairy eggs', 'produce', 'dairy eggs', 'produce', 'beverages'],
#  191: ['deli',
#   'produce',
#   'dairy eggs',
#   'breakfast',
#   'produce',
#   'international',
#   'snacks'],
#  192: ['beverages',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'snacks',
#   'breakfast',
#   'snacks',
#   'pantry'],
#  193: ['snacks', 'snacks', 'frozen', 'frozen', 'pantry', 'snacks', 'snacks'],
#  195: ['snacks', 'produce', 'produce', 'produce', 'household', 'breakfast'],
#  197: ['pantry',
#   'dry goods pasta',
#   'snacks',
#   'snacks',
#   'produce',
#   'beverages',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'meat seafood',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'snacks',
#   'snacks',
#   'snacks',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs'],
#  198: ['canned goods', 'snacks'],
#  199: ['produce',
#   'produce',
#   'produce',
#   'snacks',
#   'pantry',
#   'snacks',
#   'beverages',
#   'produce',
#   'dairy eggs'],
#  201: ['dairy eggs', 'dairy eggs', 'pantry'],
#  203: ['dairy eggs'],
#  204: ['bakery',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'breakfast',
#   'frozen',
#   'bakery',
#   'produce',
#   'dry goods pasta',
#   'dry goods pasta',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'other',
#   'pantry',
#   'produce',
#   'produce'],
#  205: ['beverages',
#   'produce',
#   'bakery',
#   'frozen',
#   'meat seafood',
#   'produce',
#   'dairy eggs',
#   'canned goods'],
#  206: ['snacks', 'deli', 'deli', 'deli', 'deli', 'produce', 'produce', 'deli'],
#  208: ['deli', 'produce', 'produce', 'produce', 'dairy eggs'],
#  209: ['snacks',
#   'snacks',
#   'snacks',
#   'snacks',
#   'snacks',
#   'produce',
#   'snacks',
#   'snacks',
#   'snacks'],
#  210: ['dairy eggs',
#   'produce',
#   'produce',
#   'frozen',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'dry goods pasta',
#   'dairy eggs',
#   'frozen',
#   'frozen',
#   'produce',
#   'canned goods',
#   'frozen',
#   'dairy eggs',
#   'produce',
#   'pantry',
#   'international',
#   'deli'],
#  211: ['produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'beverages',
#   'produce',
#   'canned goods',
#   'canned goods',
#   'canned goods',
#   'canned goods',
#   'canned goods',
#   'dry goods pasta',
#   'dry goods pasta',
#   'dry goods pasta',
#   'international',
#   'international',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'frozen',
#   'produce',
#   'produce',
#   'produce'],
#  212: ['dairy eggs', 'international', 'beverages'],
#  213: ['dairy eggs',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'pantry',
#   'dairy eggs',
#   'personal care',
#   'pantry',
#   'snacks',
#   'snacks',
#   'produce',
#   'canned goods',
#   'canned goods',
#   'canned goods',
#   'pantry',
#   'pantry',
#   'bakery',
#   'produce',
#   'pantry',
#   'canned goods',
#   'dairy eggs',
#   'produce',
#   'pantry',
#   'produce',
#   'pantry'],
#  214: ['dairy eggs',
#   'pantry',
#   'produce',
#   'produce',
#   'pantry',
#   'frozen',
#   'canned goods',
#   'produce',
#   'produce',
#   'pantry',
#   'pantry',
#   'pantry',
#   'produce',
#   'produce',
#   'frozen',
#   'produce',
#   'pantry',
#   'produce',
#   'pantry',
#   'deli',
#   'pantry',
#   'canned goods',
#   'dry goods pasta',
#   'produce',
#   'deli',
#   'deli',
#   'pantry',
#   'deli',
#   'produce',
#   'beverages',
#   'beverages',
#   'dairy eggs',
#   'beverages',
#   'beverages',
#   'beverages',
#   'dairy eggs'],
#  215: ['dry goods pasta',
#   'produce',
#   'dry goods pasta',
#   'dairy eggs',
#   'beverages',
#   'beverages',
#   'dry goods pasta',
#   'pantry',
#   'international',
#   'household',
#   'bakery',
#   'snacks',
#   'produce',
#   'beverages'],
#  217: ['dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'personal care',
#   'meat seafood',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'snacks',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs'],
#  218: ['snacks'],
#  219: ['breakfast',
#   'dairy eggs',
#   'breakfast',
#   'beverages',
#   'produce',
#   'dry goods pasta',
#   'household',
#   'beverages',
#   'snacks',
#   'dairy eggs',
#   'beverages',
#   'snacks',
#   'meat seafood',
#   'pantry',
#   'meat seafood',
#   'bakery',
#   'bakery',
#   'dairy eggs',
#   'dairy eggs',
#   'deli',
#   'produce',
#   'dairy eggs',
#   'beverages'],
#  220: ['dairy eggs', 'dairy eggs', 'dairy eggs', 'frozen', 'dairy eggs'],
#  222: ['beverages',
#   'dairy eggs',
#   'household',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs'],
#  223: ['snacks', 'deli', 'produce'],
#  224: ['produce',
#   'beverages',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'dry goods pasta'],
#  226: ['produce',
#   'breakfast',
#   'frozen',
#   'dairy eggs',
#   'deli',
#   'frozen',
#   'frozen',
#   'breakfast',
#   'pantry',
#   'produce',
#   'dry goods pasta',
#   'canned goods',
#   'breakfast',
#   'pantry'],
#  229: ['household',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'beverages',
#   'beverages'],
#  230: ['snacks',
#   'snacks',
#   'dairy eggs',
#   'dairy eggs',
#   'snacks',
#   'deli',
#   'snacks',
#   'dairy eggs',
#   'produce',
#   'frozen',
#   'dry goods pasta',
#   'produce',
#   'dry goods pasta',
#   'produce',
#   'produce',
#   'produce',
#   'pantry'],
#  231: ['produce',
#   'dairy eggs',
#   'dairy eggs',
#   'bakery',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'snacks',
#   'snacks',
#   'snacks',
#   'produce',
#   'produce',
#   'snacks',
#   'produce',
#   'meat seafood',
#   'dairy eggs',
#   'produce',
#   'produce'],
#  235: ['beverages',
#   'beverages',
#   'frozen',
#   'produce',
#   'personal care',
#   'household',
#   'household',
#   'beverages',
#   'produce',
#   'pantry',
#   'frozen',
#   'snacks',
#   'deli'],
#  238: ['deli',
#   'dairy eggs',
#   'bakery',
#   'deli',
#   'beverages',
#   'dairy eggs',
#   'dairy eggs',
#   'beverages',
#   'dairy eggs',
#   'bakery',
#   'breakfast',
#   'bakery',
#   'dairy eggs',
#   'pets',
#   'canned goods',
#   'pantry',
#   'beverages',
#   'beverages',
#   'dairy eggs',
#   'pets',
#   'dairy eggs',
#   'beverages',
#   'frozen',
#   'pantry',
#   'dairy eggs',
#   'pantry',
#   'pantry',
#   'dairy eggs',
#   'produce',
#   'canned goods',
#   'frozen',
#   'pantry',
#   'dairy eggs',
#   'dairy eggs',
#   'dry goods pasta',
#   'canned goods',
#   'canned goods',
#   'beverages',
#   'frozen',
#   'frozen',
#   'frozen',
#   'dry goods pasta',
#   'dry goods pasta',
#   'dry goods pasta',
#   'dry goods pasta',
#   'dry goods pasta',
#   'produce',
#   'breakfast',
#   'pantry',
#   'frozen',
#   'pantry',
#   'meat seafood',
#   'bakery',
#   'pantry',
#   'snacks',
#   'meat seafood',
#   'breakfast'],
#  239: ['produce',
#   'canned goods',
#   'produce',
#   'frozen',
#   'produce',
#   'beverages',
#   'meat seafood',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce'],
#  240: ['dairy eggs', 'snacks'],
#  242: ['bakery', 'dairy eggs', 'frozen', 'beverages', 'bakery'],
#  243: ['produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce'],
#  245: ['dairy eggs',
#   'snacks',
#   'beverages',
#   'deli',
#   'produce',
#   'international',
#   'dairy eggs',
#   'beverages',
#   'produce',
#   'produce',
#   'personal care'],
#  249: ['produce', 'produce', 'produce', 'snacks'],
#  250: ['dairy eggs',
#   'personal care',
#   'household',
#   'bakery',
#   'dairy eggs',
#   'frozen',
#   'canned goods',
#   'dairy eggs',
#   'frozen',
#   'dairy eggs',
#   'dry goods pasta',
#   'frozen',
#   'dairy eggs'],
#  252: ['dairy eggs',
#   'bakery',
#   'pantry',
#   'dairy eggs',
#   'frozen',
#   'deli',
#   'bakery',
#   'bakery',
#   'produce',
#   'pantry',
#   'snacks',
#   'produce',
#   'pantry',
#   'produce',
#   'deli',
#   'household',
#   'household',
#   'beverages',
#   'dairy eggs',
#   'international',
#   'snacks'],
#  253: ['personal care', 'personal care', 'snacks'],
#  255: ['dairy eggs',
#   'beverages',
#   'produce',
#   'produce',
#   'snacks',
#   'deli',
#   'dairy eggs'],
#  256: ['dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'beverages',
#   'household',
#   'bakery',
#   'breakfast',
#   'dairy eggs',
#   'produce',
#   'pantry'],
#  258: ['breakfast', 'beverages', 'deli', 'snacks', 'produce'],
#  259: ['pantry', 'pantry', 'pantry', 'pantry'],
#  260: ['produce', 'produce', 'produce', 'produce'],
#  261: ['beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'international',
#   'snacks',
#   'breakfast',
#   'international',
#   'breakfast',
#   'snacks',
#   'missing',
#   'produce',
#   'dairy eggs'],
#  262: ['dairy eggs', 'dairy eggs', 'bakery', 'snacks'],
#  264: ['dry goods pasta',
#   'bakery',
#   'produce',
#   'canned goods',
#   'pantry',
#   'canned goods',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'international',
#   'beverages',
#   'frozen',
#   'frozen',
#   'personal care',
#   'frozen',
#   'produce',
#   'deli',
#   'pantry'],
#  267: ['alcohol',
#   'deli',
#   'frozen',
#   'snacks',
#   'pantry',
#   'snacks',
#   'deli',
#   'beverages',
#   'beverages',
#   'dairy eggs',
#   'snacks',
#   'snacks',
#   'pantry',
#   'meat seafood',
#   'frozen'],
#  270: ['produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce'],
#  271: ['beverages'],
#  272: ['snacks',
#   'snacks',
#   'snacks',
#   'snacks',
#   'personal care',
#   'dairy eggs',
#   'snacks',
#   'snacks'],
#  273: ['produce',
#   'bakery',
#   'bakery',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce'],
#  278: ['dairy eggs'],
#  280: ['breakfast',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'canned goods',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs'],
#  282: ['frozen',
#   'frozen',
#   'snacks',
#   'snacks',
#   'babies',
#   'household',
#   'beverages'],
#  283: ['frozen', 'produce', 'produce', 'produce', 'frozen', 'pantry'],
#  284: ['dairy eggs',
#   'dairy eggs',
#   'breakfast',
#   'breakfast',
#   'dairy eggs',
#   'canned goods',
#   'dry goods pasta',
#   'dry goods pasta',
#   'personal care',
#   'personal care',
#   'produce',
#   'household',
#   'dry goods pasta'],
#  285: ['produce',
#   'household',
#   'household',
#   'produce',
#   'pantry',
#   'breakfast',
#   'breakfast'],
#  286: ['babies', 'babies'],
#  288: ['babies',
#   'babies',
#   'babies',
#   'babies',
#   'babies',
#   'produce',
#   'produce',
#   'frozen',
#   'produce',
#   'bakery',
#   'dairy eggs'],
#  289: ['produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'snacks',
#   'beverages',
#   'breakfast'],
#  291: ['produce'],
#  293: ['snacks',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'personal care',
#   'personal care',
#   'dairy eggs',
#   'frozen',
#   'dairy eggs',
#   'frozen',
#   'canned goods',
#   'bakery',
#   'produce',
#   'frozen',
#   'produce',
#   'canned goods'],
#  294: ['produce', 'beverages', 'produce', 'produce', 'produce', 'household'],
#  295: ['beverages',
#   'beverages',
#   'beverages',
#   'produce',
#   'produce',
#   'deli',
#   'frozen',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'snacks',
#   'bulk'],
#  296: ['babies',
#   'babies',
#   'babies',
#   'bakery',
#   'bakery',
#   'produce',
#   'pantry',
#   'babies',
#   'babies',
#   'babies',
#   'babies',
#   'babies',
#   'missing'],
#  298: ['beverages',
#   'meat seafood',
#   'beverages',
#   'beverages',
#   'deli',
#   'frozen',
#   'canned goods',
#   'produce',
#   'snacks',
#   'personal care',
#   'frozen',
#   'canned goods',
#   'bakery',
#   'pantry',
#   'snacks',
#   'frozen',
#   'frozen',
#   'pantry'],
#  300: ['breakfast',
#   'breakfast',
#   'breakfast',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'breakfast',
#   'beverages',
#   'produce',
#   'frozen',
#   'frozen',
#   'frozen',
#   'frozen',
#   'canned goods',
#   'canned goods'],
#  304: ['snacks',
#   'dairy eggs',
#   'beverages',
#   'dairy eggs',
#   'dairy eggs',
#   'breakfast'],
#  305: ['dairy eggs',
#   'produce',
#   'beverages',
#   'frozen',
#   'snacks',
#   'produce',
#   'snacks',
#   'snacks',
#   'produce',
#   'produce',
#   'bakery'],
#  306: ['produce', 'produce', 'dairy eggs', 'produce'],
#  309: ['produce',
#   'produce',
#   'pantry',
#   'pantry',
#   'produce',
#   'canned goods',
#   'dry goods pasta',
#   'produce',
#   'pantry',
#   'dairy eggs',
#   'dry goods pasta',
#   'pantry',
#   'dairy eggs',
#   'produce'],
#  310: ['frozen', 'dairy eggs', 'household', 'other'],
#  313: ['produce',
#   'produce',
#   'babies',
#   'dairy eggs',
#   'produce',
#   'canned goods'],
#  314: ['alcohol'],
#  315: ['bakery',
#   'produce',
#   'produce',
#   'meat seafood',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'alcohol',
#   'other',
#   'international',
#   'dairy eggs'],
#  317: ['snacks', 'meat seafood', 'frozen'],
#  319: ['produce',
#   'canned goods',
#   'produce',
#   'frozen',
#   'pantry',
#   'produce',
#   'pantry',
#   'dairy eggs',
#   'pantry'],
#  322: ['produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'breakfast',
#   'produce'],
#  323: ['dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'breakfast',
#   'breakfast',
#   'breakfast',
#   'breakfast',
#   'breakfast',
#   'breakfast',
#   'beverages',
#   'pantry'],
#  324: ['beverages', 'dairy eggs', 'produce', 'frozen', 'frozen', 'frozen'],
#  325: ['pantry',
#   'dry goods pasta',
#   'dry goods pasta',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs'],
#  326: ['snacks', 'snacks', 'produce'],
#  327: ['snacks',
#   'snacks',
#   'beverages',
#   'deli',
#   'deli',
#   'dairy eggs',
#   'beverages',
#   'bakery',
#   'dairy eggs',
#   'frozen',
#   'bakery'],
#  328: ['pets', 'dairy eggs', 'pantry'],
#  329: ['dairy eggs',
#   'produce',
#   'bakery',
#   'frozen',
#   'bakery',
#   'dairy eggs',
#   'breakfast',
#   'breakfast',
#   'breakfast',
#   'dairy eggs',
#   'canned goods',
#   'produce',
#   'canned goods',
#   'canned goods',
#   'canned goods',
#   'deli',
#   'pantry',
#   'breakfast',
#   'pantry',
#   'snacks',
#   'produce',
#   'pantry',
#   'produce'],
#  330: ['beverages',
#   'personal care',
#   'personal care',
#   'personal care',
#   'personal care'],
#  334: ['pantry',
#   'pantry',
#   'dairy eggs',
#   'frozen',
#   'frozen',
#   'dry goods pasta'],
#  337: ['dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'beverages',
#   'beverages',
#   'household',
#   'deli',
#   'snacks',
#   'dairy eggs',
#   'snacks',
#   'snacks',
#   'produce',
#   'produce',
#   'frozen',
#   'dairy eggs',
#   'breakfast',
#   'canned goods',
#   'deli',
#   'produce',
#   'canned goods',
#   'canned goods',
#   'international'],
#  340: ['produce',
#   'bakery',
#   'produce',
#   'produce',
#   'deli',
#   'beverages',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'frozen'],
#  341: ['produce',
#   'produce',
#   'bakery',
#   'produce',
#   'produce',
#   'frozen',
#   'beverages',
#   'deli',
#   'canned goods',
#   'canned goods',
#   'snacks',
#   'beverages',
#   'beverages',
#   'beverages',
#   'produce',
#   'personal care',
#   'household',
#   'household',
#   'beverages',
#   'personal care',
#   'frozen'],
#  342: ['beverages',
#   'frozen',
#   'frozen',
#   'frozen',
#   'breakfast',
#   'frozen',
#   'produce',
#   'frozen'],
#  343: ['dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'pantry',
#   'dairy eggs',
#   'produce'],
#  345: ['dairy eggs', 'beverages'],
#  346: ['beverages', 'beverages', 'beverages'],
#  348: ['other', 'produce', 'bakery', 'pantry'],
#  349: ['deli', 'dairy eggs', 'produce', 'produce', 'bakery', 'produce'],
#  350: ['dairy eggs',
#   'dairy eggs',
#   'canned goods',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dry goods pasta',
#   'frozen',
#   'meat seafood',
#   'produce',
#   'produce',
#   'snacks',
#   'dry goods pasta',
#   'international',
#   'produce',
#   'frozen',
#   'produce'],
#  351: ['dairy eggs',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'dry goods pasta',
#   'produce',
#   'deli',
#   'frozen',
#   'frozen',
#   'deli',
#   'produce'],
#  353: ['beverages',
#   'babies',
#   'personal care',
#   'household',
#   'dairy eggs',
#   'beverages',
#   'beverages',
#   'snacks',
#   'snacks',
#   'beverages',
#   'personal care',
#   'dairy eggs'],
#  355: ['produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'pantry',
#   'frozen',
#   'frozen',
#   'canned goods',
#   'dairy eggs',
#   'dairy eggs',
#   'snacks',
#   'dairy eggs',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'breakfast'],
#  357: ['produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'frozen',
#   'produce',
#   'breakfast',
#   'bakery',
#   'snacks',
#   'snacks',
#   'snacks',
#   'dry goods pasta',
#   'dry goods pasta',
#   'snacks',
#   'frozen',
#   'snacks',
#   'produce',
#   'produce'],
#  358: ['produce', 'produce', 'dairy eggs', 'produce'],
#  359: ['dairy eggs',
#   'produce',
#   'personal care',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'canned goods',
#   'bakery',
#   'beverages',
#   'meat seafood',
#   'dry goods pasta',
#   'meat seafood',
#   'pantry',
#   'dry goods pasta',
#   'produce',
#   'pantry',
#   'pantry',
#   'snacks'],
#  361: ['dry goods pasta'],
#  363: ['beverages',
#   'bakery',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'produce',
#   'produce',
#   'produce',
#   'dry goods pasta',
#   'pantry',
#   'pantry'],
#  365: ['dairy eggs'],
#  370: ['produce', 'bakery', 'snacks', 'produce', 'other', 'pantry', 'frozen'],
#  371: ['snacks',
#   'produce',
#   'deli',
#   'dairy eggs',
#   'frozen',
#   'dry goods pasta',
#   'breakfast'],
#  372: ['beverages',
#   'household',
#   'produce',
#   'household',
#   'household',
#   'frozen'],
#  374: ['beverages', 'snacks'],
#  375: ['bakery',
#   'snacks',
#   'beverages',
#   'produce',
#   'household',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'snacks',
#   'dairy eggs',
#   'snacks',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'household',
#   'produce',
#   'canned goods',
#   'beverages',
#   'dairy eggs',
#   'bakery',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'snacks',
#   'pantry',
#   'meat seafood',
#   'deli',
#   'household',
#   'pantry',
#   'dairy eggs',
#   'canned goods',
#   'beverages',
#   'dry goods pasta',
#   'produce',
#   'produce',
#   'produce',
#   'deli',
#   'produce',
#   'pantry',
#   'dairy eggs',
#   'snacks'],
#  376: ['bakery',
#   'frozen',
#   'deli',
#   'frozen',
#   'frozen',
#   'meat seafood',
#   'frozen',
#   'frozen',
#   'beverages',
#   'beverages',
#   'pantry',
#   'pantry',
#   'household'],
#  377: ['canned goods', 'dairy eggs', 'produce', 'dairy eggs', 'household'],
#  378: ['beverages', 'household', 'personal care'],
#  379: ['pantry'],
#  380: ['deli', 'deli', 'deli', 'deli'],
#  382: ['beverages',
#   'dairy eggs',
#   'dairy eggs',
#   'frozen',
#   'beverages',
#   'beverages',
#   'produce',
#   'meat seafood',
#   'dairy eggs',
#   'bakery',
#   'produce',
#   'meat seafood'],
#  383: ['frozen', 'produce', 'produce', 'produce', 'produce'],
#  384: ['produce', 'canned goods', 'canned goods', 'beverages', 'snacks'],
#  385: ['produce',
#   'dairy eggs',
#   'international',
#   'produce',
#   'produce',
#   'produce',
#   'beverages',
#   'beverages',
#   'personal care'],
#  387: ['beverages',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'beverages',
#   'beverages'],
#  390: ['bakery',
#   'meat seafood',
#   'dairy eggs',
#   'produce',
#   'canned goods',
#   'beverages',
#   'beverages',
#   'canned goods',
#   'breakfast',
#   'breakfast',
#   'breakfast',
#   'personal care',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'meat seafood',
#   'dairy eggs',
#   'dairy eggs',
#   'beverages',
#   'produce',
#   'dry goods pasta',
#   'dry goods pasta',
#   'beverages',
#   'beverages',
#   'personal care',
#   'produce',
#   'produce',
#   'produce',
#   'household',
#   'produce'],
#  391: ['produce',
#   'produce',
#   'dairy eggs',
#   'snacks',
#   'dairy eggs',
#   'produce',
#   'pantry',
#   'frozen',
#   'produce',
#   'dairy eggs'],
#  393: ['dairy eggs',
#   'bakery',
#   'frozen',
#   'produce',
#   'snacks',
#   'dairy eggs',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce'],
#  395: ['beverages'],
#  396: ['bakery',
#   'breakfast',
#   'produce',
#   'produce',
#   'beverages',
#   'bakery',
#   'personal care',
#   'personal care'],
#  399: ['dairy eggs',
#   'frozen',
#   'bakery',
#   'beverages',
#   'beverages',
#   'beverages'],
#  401: ['produce',
#   'produce',
#   'canned goods',
#   'produce',
#   'meat seafood',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dry goods pasta',
#   'dry goods pasta',
#   'dairy eggs',
#   'pantry',
#   'bakery',
#   'produce',
#   'dairy eggs'],
#  402: ['household', 'beverages'],
#  403: ['dairy eggs',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'bakery',
#   'produce',
#   'produce',
#   'meat seafood',
#   'meat seafood',
#   'snacks',
#   'snacks',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce'],
#  404: ['produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'meat seafood',
#   'produce',
#   'beverages'],
#  406: ['produce',
#   'produce',
#   'produce',
#   'meat seafood',
#   'beverages',
#   'beverages',
#   'beverages'],
#  409: ['dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'snacks',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'meat seafood',
#   'meat seafood',
#   'dairy eggs',
#   'produce',
#   'dairy eggs'],
#  411: ['frozen',
#   'produce',
#   'frozen',
#   'frozen',
#   'frozen',
#   'frozen',
#   'beverages',
#   'dry goods pasta'],
#  412: ['produce',
#   'produce',
#   'dairy eggs',
#   'deli',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'beverages',
#   'frozen',
#   'frozen'],
#  414: ['produce', 'babies', 'babies', 'produce'],
#  416: ['dairy eggs',
#   'snacks',
#   'meat seafood',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'snacks',
#   'snacks',
#   'frozen',
#   'frozen',
#   'produce',
#   'produce',
#   'produce'],
#  417: ['household',
#   'household',
#   'frozen',
#   'frozen',
#   'pantry',
#   'meat seafood',
#   'frozen'],
#  419: ['international', 'snacks', 'beverages', 'beverages', 'beverages'],
#  421: ['dairy eggs', 'beverages', 'pantry', 'bakery'],
#  425: ['dairy eggs',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'canned goods',
#   'deli',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'dry goods pasta',
#   'frozen',
#   'produce',
#   'snacks',
#   'produce'],
#  426: ['snacks', 'snacks', 'produce', 'dairy eggs'],
#  429: ['beverages',
#   'personal care',
#   'personal care',
#   'personal care',
#   'pantry',
#   'beverages'],
#  430: ['produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'bakery',
#   'produce',
#   'produce',
#   'meat seafood',
#   'international'],
#  431: ['meat seafood', 'beverages'],
#  432: ['meat seafood',
#   'produce',
#   'bakery',
#   'produce',
#   'beverages',
#   'beverages',
#   'produce',
#   'beverages',
#   'produce'],
#  433: ['produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'pantry',
#   'produce',
#   'produce',
#   'pantry'],
#  434: ['beverages',
#   'beverages',
#   'household',
#   'produce',
#   'meat seafood',
#   'personal care',
#   'personal care',
#   'deli',
#   'deli'],
#  435: ['beverages',
#   'breakfast',
#   'breakfast',
#   'household',
#   'snacks',
#   'household',
#   'dairy eggs',
#   'dairy eggs',
#   'meat seafood',
#   'snacks',
#   'household',
#   'household',
#   'household',
#   'snacks'],
#  437: ['pantry',
#   'breakfast',
#   'frozen',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'beverages',
#   'snacks',
#   'produce',
#   'canned goods',
#   'dairy eggs'],
#  438: ['beverages',
#   'dairy eggs',
#   'produce',
#   'beverages',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'frozen',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs'],
#  441: ['snacks', 'snacks', 'snacks', 'produce'],
#  442: ['dairy eggs',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'beverages',
#   'breakfast',
#   'breakfast',
#   'breakfast',
#   'breakfast',
#   'beverages',
#   'beverages',
#   'beverages',
#   'pets'],
#  444: ['snacks',
#   'pantry',
#   'bakery',
#   'deli',
#   'produce',
#   'deli',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'deli',
#   'frozen',
#   'dairy eggs',
#   'produce',
#   'pantry'],
#  446: ['beverages',
#   'frozen',
#   'dairy eggs',
#   'pantry',
#   'produce',
#   'beverages',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'beverages',
#   'produce',
#   'household',
#   'household',
#   'beverages',
#   'alcohol',
#   'missing',
#   'snacks',
#   'dairy eggs',
#   'dry goods pasta',
#   'snacks'],
#  448: ['pantry',
#   'produce',
#   'dairy eggs',
#   'snacks',
#   'bakery',
#   'bakery',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'beverages',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'breakfast',
#   'canned goods',
#   'dairy eggs',
#   'produce'],
#  449: ['bakery',
#   'deli',
#   'snacks',
#   'produce',
#   'frozen',
#   'produce',
#   'dairy eggs'],
#  452: ['produce',
#   'produce',
#   'beverages',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'deli',
#   'canned goods',
#   'produce',
#   'frozen',
#   'household',
#   'dairy eggs',
#   'frozen'],
#  453: ['produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'bakery'],
#  454: ['produce',
#   'deli',
#   'dairy eggs',
#   'beverages',
#   'snacks',
#   'beverages',
#   'pantry',
#   'produce',
#   'meat seafood',
#   'frozen',
#   'pantry',
#   'bakery',
#   'snacks'],
#  456: ['deli', 'deli', 'dairy eggs', 'deli', 'deli', 'snacks'],
#  457: ['produce', 'produce', 'produce', 'dairy eggs', 'snacks'],
#  459: ['produce', 'breakfast', 'produce', 'produce', 'produce', 'dairy eggs'],
#  465: ['babies',
#   'babies',
#   'babies',
#   'babies',
#   'babies',
#   'babies',
#   'babies',
#   'babies',
#   'produce',
#   'beverages',
#   'snacks',
#   'produce',
#   'dairy eggs',
#   'produce'],
#  466: ['frozen',
#   'bakery',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'missing',
#   'missing',
#   'snacks',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'pantry',
#   'dairy eggs',
#   'frozen',
#   'pantry',
#   'canned goods',
#   'snacks',
#   'pantry',
#   'international',
#   'deli',
#   'produce',
#   'pantry',
#   'deli',
#   'deli',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'dairy eggs'],
#  468: ['dairy eggs', 'produce', 'produce', 'breakfast', 'produce'],
#  469: ['frozen', 'dairy eggs', 'dairy eggs', 'beverages', 'produce'],
#  470: ['dairy eggs', 'produce', 'beverages', 'dairy eggs', 'produce'],
#  471: ['bakery',
#   'dairy eggs',
#   'frozen',
#   'dairy eggs',
#   'frozen',
#   'meat seafood',
#   'dry goods pasta',
#   'frozen',
#   'dairy eggs',
#   'household',
#   'snacks',
#   'beverages',
#   'pets',
#   'frozen',
#   'personal care',
#   'produce',
#   'dairy eggs',
#   'dry goods pasta',
#   'frozen',
#   'pets',
#   'snacks',
#   'dry goods pasta'],
#  472: ['produce', 'produce'],
#  473: ['produce',
#   'bakery',
#   'beverages',
#   'pantry',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'meat seafood',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'pantry',
#   'breakfast',
#   'snacks',
#   'pantry',
#   'dairy eggs',
#   'dairy eggs',
#   'snacks',
#   'international',
#   'pantry',
#   'produce',
#   'pantry',
#   'pantry',
#   'canned goods',
#   'produce',
#   'pantry',
#   'pantry',
#   'bakery'],
#  475: ['dairy eggs', 'frozen', 'beverages', 'frozen'],
#  476: ['dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'deli',
#   'pantry',
#   'deli',
#   'babies',
#   'produce',
#   'babies',
#   'babies',
#   'babies',
#   'produce',
#   'frozen'],
#  477: ['produce'],
#  478: ['beverages',
#   'produce',
#   'snacks',
#   'meat seafood',
#   'household',
#   'international',
#   'snacks'],
#  479: ['frozen',
#   'dry goods pasta',
#   'snacks',
#   'beverages',
#   'frozen',
#   'snacks',
#   'snacks',
#   'snacks',
#   'pantry',
#   'dry goods pasta',
#   'dry goods pasta'],
#  480: ['produce',
#   'produce',
#   'produce',
#   'household',
#   'beverages',
#   'meat seafood',
#   'frozen',
#   'dry goods pasta',
#   'frozen',
#   'missing',
#   'snacks',
#   'snacks',
#   'breakfast'],
#  481: ['produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce'],
#  483: ['household'],
#  484: ['produce'],
#  486: ['produce',
#   'dairy eggs',
#   'produce',
#   'deli',
#   'produce',
#   'deli',
#   'produce',
#   'dairy eggs',
#   'deli',
#   'deli',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'beverages',
#   'personal care',
#   'produce',
#   'produce',
#   'beverages',
#   'produce',
#   'dry goods pasta',
#   'produce',
#   'snacks',
#   'produce',
#   'produce',
#   'beverages',
#   'dry goods pasta',
#   'produce',
#   'produce',
#   'produce',
#   'frozen',
#   'bakery'],
#  487: ['deli',
#   'deli',
#   'dairy eggs',
#   'dairy eggs',
#   'snacks',
#   'beverages',
#   'international',
#   'snacks',
#   'dairy eggs',
#   'deli',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'snacks',
#   'bakery',
#   'snacks',
#   'dry goods pasta',
#   'snacks',
#   'snacks',
#   'canned goods',
#   'frozen',
#   'breakfast',
#   'dry goods pasta',
#   'frozen',
#   'personal care',
#   'frozen',
#   'pantry',
#   'frozen'],
#  488: ['dry goods pasta',
#   'pantry',
#   'breakfast',
#   'dry goods pasta',
#   'dairy eggs',
#   'dry goods pasta',
#   'breakfast',
#   'snacks',
#   'dairy eggs',
#   'dairy eggs',
#   'snacks',
#   'produce',
#   'snacks',
#   'frozen',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'canned goods',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'breakfast',
#   'breakfast'],
#  489: ['produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce'],
#  490: ['frozen'],
#  491: ['bakery',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'pantry',
#   'beverages',
#   'household'],
#  493: ['produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'breakfast',
#   'deli',
#   'frozen',
#   'pantry',
#   'produce',
#   'deli',
#   'canned goods',
#   'produce',
#   'pantry',
#   'frozen'],
#  494: ['produce',
#   'produce',
#   'canned goods',
#   'frozen',
#   'snacks',
#   'snacks',
#   'snacks',
#   'produce',
#   'snacks',
#   'bakery',
# ...
#   'dry goods pasta',
#   'beverages',
#   'breakfast',
#   'breakfast',
#   'produce',
#   'snacks',
#   'dairy eggs'],
#  1402: ['produce',
#   'personal care',
#   'produce',
#   'produce',
#   'bakery',
#   'snacks',
#   'canned goods'],
#  1403: ['dairy eggs',
#   'deli',
#   'frozen',
#   'deli',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce'],
#  1405: ['frozen',
#   'beverages',
#   'beverages',
#   'dairy eggs',
#   'beverages',
#   'household',
#   'dry goods pasta'],
#  1406: ['meat seafood',
#   'produce',
#   'produce',
#   'pantry',
#   'pantry',
#   'meat seafood'],
#  1407: ['international', 'snacks'],
#  1410: ['beverages',
#   'dairy eggs',
#   'beverages',
#   'frozen',
#   'pantry',
#   'snacks',
#   'beverages',
#   'produce',
#   'produce',
#   'personal care',
#   'babies'],
#  1412: ['beverages', 'dairy eggs', 'frozen'],
#  1414: ['dairy eggs',
#   'snacks',
#   'dry goods pasta',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'pantry',
#   'frozen',
#   'dairy eggs',
#   'pantry'],
#  1418: ['frozen',
#   'canned goods',
#   'snacks',
#   'missing',
#   'frozen',
#   'snacks',
#   'dairy eggs',
#   'meat seafood',
#   'produce',
#   'beverages',
#   'dairy eggs',
#   'household',
#   'personal care',
#   'beverages'],
#  1422: ['frozen',
#   'frozen',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'beverages',
#   'frozen',
#   'bakery',
#   'pantry'],
#  1423: ['dairy eggs',
#   'frozen',
#   'snacks',
#   'dairy eggs',
#   'snacks',
#   'frozen',
#   'snacks',
#   'snacks',
#   'snacks',
#   'frozen',
#   'frozen',
#   'deli',
#   'dairy eggs',
#   'frozen',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'pantry'],
#  1425: ['produce',
#   'produce',
#   'dairy eggs',
#   'household',
#   'household',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'deli',
#   'produce',
#   'deli'],
#  1426: ['beverages',
#   'produce',
#   'produce',
#   'beverages',
#   'dairy eggs',
#   'produce',
#   'pantry',
#   'beverages',
#   'produce',
#   'produce',
#   'pantry',
#   'bakery',
#   'dairy eggs',
#   'snacks'],
#  1427: ['personal care', 'personal care', 'produce', 'beverages'],
#  1428: ['meat seafood', 'produce', 'dairy eggs'],
#  1432: ['produce',
#   'international',
#   'produce',
#   'produce',
#   'beverages',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'frozen',
#   'bulk',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'dry goods pasta',
#   'beverages'],
#  1435: ['pantry',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'international',
#   'produce'],
#  1436: ['snacks',
#   'produce',
#   'deli',
#   'dry goods pasta',
#   'beverages',
#   'produce',
#   'produce',
#   'frozen',
#   'snacks',
#   'dairy eggs',
#   'produce'],
#  1437: ['personal care',
#   'personal care',
#   'frozen',
#   'pantry',
#   'dairy eggs',
#   'snacks',
#   'frozen'],
#  1439: ['bakery',
#   'produce',
#   'produce',
#   'snacks',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'deli',
#   'beverages',
#   'beverages',
#   'dairy eggs',
#   'snacks',
#   'frozen',
#   'dairy eggs',
#   'pantry',
#   'produce'],
#  1440: ['produce',
#   'frozen',
#   'snacks',
#   'dairy eggs',
#   'dairy eggs',
#   'bakery',
#   'breakfast',
#   'breakfast',
#   'personal care',
#   'snacks',
#   'snacks'],
#  1442: ['frozen',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'pantry',
#   'produce',
#   'pantry',
#   'bakery',
#   'beverages',
#   'deli',
#   'deli'],
#  1443: ['dairy eggs', 'household', 'dairy eggs'],
#  1446: ['dairy eggs',
#   'produce',
#   'meat seafood',
#   'canned goods',
#   'personal care',
#   'dairy eggs',
#   'pantry',
#   'pantry',
#   'produce',
#   'bakery',
#   'dairy eggs',
#   'personal care',
#   'produce',
#   'produce',
#   'pantry'],
#  1447: ['dairy eggs',
#   'beverages',
#   'produce',
#   'produce',
#   'pantry',
#   'dairy eggs'],
#  1448: ['produce', 'produce', 'produce'],
#  1449: ['beverages',
#   'pantry',
#   'beverages',
#   'pantry',
#   'dry goods pasta',
#   'pantry',
#   'snacks',
#   'pantry',
#   'produce',
#   'frozen',
#   'produce'],
#  1451: ['beverages', 'breakfast'],
#  1456: ['dairy eggs', 'dairy eggs', 'snacks'],
#  1457: ['beverages', 'beverages', 'beverages', 'beverages', 'dairy eggs'],
#  1458: ['deli', 'produce', 'pantry', 'breakfast', 'dairy eggs'],
#  1459: ['dairy eggs',
#   'household',
#   'other',
#   'household',
#   'beverages',
#   'snacks',
#   'personal care',
#   'pantry',
#   'snacks',
#   'babies',
#   'babies',
#   'beverages',
#   'bakery',
#   'dairy eggs',
#   'dry goods pasta',
#   'babies',
#   'babies',
#   'produce',
#   'produce',
#   'pantry',
#   'deli',
#   'deli',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'breakfast',
#   'pantry',
#   'household'],
#  1461: ['dairy eggs', 'beverages'],
#  1462: ['pantry', 'beverages'],
#  1465: ['meat seafood',
#   'bakery',
#   'produce',
#   'produce',
#   'bakery',
#   'breakfast',
#   'dairy eggs',
#   'produce',
#   'frozen',
#   'frozen',
#   'dairy eggs',
#   'beverages'],
#  1466: ['produce'],
#  1468: ['babies', 'produce'],
#  1470: ['produce', 'pantry', 'produce'],
#  1472: ['pantry', 'dairy eggs', 'produce', 'bakery'],
#  1474: ['alcohol',
#   'produce',
#   'meat seafood',
#   'snacks',
#   'beverages',
#   'meat seafood',
#   'produce'],
#  1475: ['beverages',
#   'produce',
#   'pantry',
#   'dairy eggs',
#   'canned goods',
#   'produce',
#   'produce'],
#  1476: ['snacks',
#   'snacks',
#   'frozen',
#   'frozen',
#   'snacks',
#   'breakfast',
#   'dry goods pasta',
#   'produce',
#   'breakfast',
#   'breakfast',
#   'frozen',
#   'snacks',
#   'snacks',
#   'breakfast',
#   'breakfast',
#   'pantry',
#   'snacks',
#   'snacks',
#   'snacks',
#   'frozen',
#   'frozen',
#   'frozen',
#   'frozen',
#   'breakfast',
#   'dairy eggs',
#   'household',
#   'deli',
#   'produce',
#   'personal care'],
#  1477: ['snacks',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'snacks',
#   'frozen',
#   'produce',
#   'canned goods',
#   'meat seafood',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'meat seafood',
#   'produce',
#   'babies',
#   'babies',
#   'babies',
#   'babies',
#   'babies',
#   'babies',
#   'produce',
#   'produce',
#   'produce'],
#  1478: ['snacks',
#   'meat seafood',
#   'produce',
#   'babies',
#   'babies',
#   'babies',
#   'babies',
#   'produce',
#   'bakery',
#   'produce',
#   'breakfast',
#   'produce',
#   'breakfast',
#   'produce',
#   'snacks',
#   'bakery',
#   'bakery',
#   'household',
#   'bakery',
#   'household',
#   'produce',
#   'snacks',
#   'pantry',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'snacks',
#   'produce',
#   'snacks',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'canned goods',
#   'snacks',
#   'beverages',
#   'pantry',
#   'pantry',
#   'dairy eggs',
#   'dry goods pasta',
#   'pantry',
#   'personal care',
#   'personal care',
#   'produce',
#   'snacks',
#   'snacks'],
#  1479: ['produce',
#   'dairy eggs',
#   'missing',
#   'deli',
#   'beverages',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'personal care',
#   'frozen',
#   'produce',
#   'produce',
#   'frozen',
#   'produce',
#   'produce',
#   'dairy eggs'],
#  1481: ['deli', 'produce', 'beverages'],
#  1482: ['bakery', 'beverages', 'pantry', 'snacks'],
#  1483: ['produce',
#   'dairy eggs',
#   'dairy eggs',
#   'frozen',
#   'beverages',
#   'produce',
#   'beverages',
#   'pantry',
#   'pantry',
#   'produce',
#   'produce',
#   'frozen',
#   'pantry',
#   'dairy eggs',
#   'deli',
#   'snacks',
#   'bakery',
#   'snacks',
#   'snacks',
#   'dairy eggs',
#   'personal care',
#   'personal care',
#   'pantry',
#   'pantry'],
#  1484: ['produce',
#   'bakery',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'personal care'],
#  1486: ['beverages',
#   'snacks',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'bakery',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'breakfast',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dairy eggs'],
#  1488: ['frozen', 'frozen', 'frozen', 'frozen'],
#  1490: ['other', 'dairy eggs'],
#  1491: ['beverages',
#   'snacks',
#   'beverages',
#   'household',
#   'meat seafood',
#   'snacks'],
#  1492: ['household', 'household', 'personal care', 'household', 'produce'],
#  1494: ['snacks'],
#  1495: ['household', 'international', 'pantry'],
#  1497: ['dairy eggs'],
#  1498: ['produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'pantry',
#   'dairy eggs',
#   'frozen',
#   'bakery',
#   'produce',
#   'dairy eggs',
#   'snacks',
#   'snacks',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'frozen',
#   'produce',
#   'snacks',
#   'snacks',
#   'deli',
#   'dairy eggs',
#   'dairy eggs',
#   'breakfast',
#   'bakery',
#   'beverages',
#   'dairy eggs',
#   'frozen'],
#  1499: ['produce',
#   'snacks',
#   'produce',
#   'snacks',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'dairy eggs',
#   'beverages',
#   'produce',
#   'frozen',
#   'frozen',
#   'pantry',
#   'beverages',
#   'meat seafood',
#   'dairy eggs',
#   'dry goods pasta',
#   'bakery',
#   'snacks',
#   'missing',
#   'snacks',
#   'produce',
#   'meat seafood',
#   'snacks'],
#  1500: ['produce',
#   'dry goods pasta',
#   'dairy eggs',
#   'bakery',
#   'beverages',
#   'produce',
#   'canned goods',
#   'beverages',
#   'dairy eggs',
#   'dairy eggs',
#   'household',
#   'dairy eggs',
#   'beverages',
#   'dry goods pasta',
#   'deli',
#   'bakery',
#   'produce',
#   'pantry',
#   'produce',
#   'bakery',
#   'snacks',
#   'dry goods pasta'],
#  1503: ['produce', 'dairy eggs', 'frozen', 'produce', 'frozen'],
#  1504: ['pets',
#   'pets',
#   'household',
#   'produce',
#   'pets',
#   'snacks',
#   'beverages',
#   'frozen',
#   'pets',
#   'personal care',
#   'personal care',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'breakfast',
#   'produce',
#   'dairy eggs',
#   'frozen',
#   'produce'],
#  1505: ['produce',
#   'beverages',
#   'dairy eggs',
#   'missing',
#   'frozen',
#   'frozen',
#   'beverages',
#   'bakery',
#   'dairy eggs',
#   'snacks',
#   'dairy eggs',
#   'dairy eggs',
#   'canned goods',
#   'frozen',
#   'produce',
#   'pantry',
#   'snacks',
#   'pantry',
#   'frozen',
#   'frozen',
#   'snacks',
#   'snacks',
#   'produce',
#   'dairy eggs',
#   'pantry'],
#  1507: ['produce',
#   'produce',
#   'produce',
#   'produce',
#   'beverages',
#   'dairy eggs',
#   'produce'],
#  1508: ['bakery',
#   'deli',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'beverages',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'frozen',
#   'produce',
#   'produce',
#   'dairy eggs'],
#  1510: ['household',
#   'frozen',
#   'frozen',
#   'pantry',
#   'frozen',
#   'frozen',
#   'frozen',
#   'produce',
#   'frozen',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'deli',
#   'dairy eggs',
#   'bakery',
#   'frozen',
#   'produce',
#   'frozen',
#   'dairy eggs',
#   'snacks',
#   'dairy eggs',
#   'beverages',
#   'produce',
#   'dry goods pasta',
#   'dry goods pasta',
#   'breakfast',
#   'dry goods pasta',
#   'meat seafood'],
#  1512: ['beverages', 'produce'],
#  1513: ['produce', 'canned goods', 'frozen'],
#  1515: ['frozen', 'produce', 'produce', 'produce'],
#  1518: ['dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'frozen',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'meat seafood',
#   'produce',
#   'dairy eggs'],
#  1519: ['beverages',
#   'produce',
#   'produce',
#   'produce',
#   'bakery',
#   'bakery',
#   'beverages'],
#  1521: ['beverages',
#   'beverages',
#   'produce',
#   'snacks',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'snacks',
#   'snacks',
#   'snacks',
#   'dairy eggs',
#   'produce',
#   'missing',
#   'breakfast',
#   'breakfast',
#   'produce',
#   'deli',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'dairy eggs',
#   'beverages',
#   'beverages',
#   'beverages',
#   'produce',
#   'produce',
#   'bakery',
#   'international',
#   'international',
#   'produce',
#   'pantry'],
#  1522: ['dairy eggs',
#   'produce',
#   'dairy eggs',
#   'snacks',
#   'produce',
#   'snacks',
#   'beverages',
#   'produce'],
#  1524: ['dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'breakfast',
#   'international',
#   'pantry',
#   'frozen'],
#  1525: ['snacks'],
#  1527: ['produce',
#   'produce',
#   'bakery',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'meat seafood',
#   'bakery',
#   'snacks',
#   'produce',
#   'beverages',
#   'dry goods pasta',
#   'dry goods pasta',
#   'frozen',
#   'frozen'],
#  1528: ['dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'beverages',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'beverages',
#   'canned goods',
#   'dairy eggs',
#   'bakery',
#   'dairy eggs',
#   'canned goods',
#   'snacks',
#   'produce',
#   'produce',
#   'pantry',
#   'pantry',
#   'pantry',
#   'canned goods',
#   'dry goods pasta'],
#  1529: ['deli', 'deli', 'dairy eggs', 'produce', 'dairy eggs'],
#  1530: ['canned goods', 'dry goods pasta', 'produce', 'deli'],
#  1531: ['produce',
#   'produce',
#   'meat seafood',
#   'frozen',
#   'frozen',
#   'frozen',
#   'produce',
#   'frozen',
#   'produce',
#   'dairy eggs'],
#  1533: ['dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'bakery',
#   'produce',
#   'dairy eggs',
#   'beverages',
#   'snacks'],
#  1534: ['snacks',
#   'snacks',
#   'pets',
#   'dairy eggs',
#   'dairy eggs',
#   'breakfast',
#   'breakfast',
#   'breakfast',
#   'pantry',
#   'frozen',
#   'frozen',
#   'frozen',
#   'produce',
#   'frozen',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'pets',
#   'breakfast',
#   'household'],
#  1536: ['dairy eggs', 'beverages', 'beverages'],
#  1537: ['household',
#   'household',
#   'breakfast',
#   'breakfast',
#   'snacks',
#   'snacks',
#   'snacks',
#   'snacks',
#   'snacks',
#   'snacks',
#   'dry goods pasta',
#   'breakfast',
#   'beverages',
#   'beverages',
#   'snacks'],
#  1538: ['bakery',
#   'dairy eggs',
#   'dairy eggs',
#   'personal care',
#   'deli',
#   'snacks',
#   'dairy eggs',
#   'deli'],
#  1539: ['beverages',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'produce',
#   'beverages',
#   'breakfast',
#   'dairy eggs',
#   'snacks'],
#  1540: ['snacks',
#   'snacks',
#   'snacks',
#   'snacks',
#   'breakfast',
#   'snacks',
#   'snacks',
#   'pantry',
#   'breakfast',
#   'breakfast',
#   'beverages',
#   'snacks',
#   'dairy eggs',
#   'frozen',
#   'deli',
#   'deli',
#   'snacks',
#   'produce',
#   'produce',
#   'snacks'],
#  1541: ['produce', 'produce', 'produce', 'produce'],
#  1542: ['produce'],
#  1543: ['deli', 'frozen', 'produce', 'snacks', 'snacks', 'deli'],
#  1545: ['produce',
#   'meat seafood',
#   'produce',
#   'produce',
#   'bakery',
#   'deli',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'deli',
#   'produce'],
#  1546: ['produce', 'pantry', 'babies'],
#  1550: ['snacks',
#   'beverages',
#   'snacks',
#   'beverages',
#   'beverages',
#   'beverages',
#   'snacks',
#   'snacks',
#   'snacks',
#   'snacks',
#   'beverages',
#   'snacks'],
#  1551: ['dairy eggs',
#   'breakfast',
#   'dairy eggs',
#   'breakfast',
#   'dairy eggs',
#   'frozen',
#   'frozen',
#   'frozen'],
#  1552: ['dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'deli',
#   'produce',
#   'produce',
#   'dry goods pasta',
#   'pantry',
#   'produce',
#   'canned goods',
#   'meat seafood',
#   'pantry',
#   'frozen',
#   'pantry',
#   'beverages',
#   'beverages',
#   'pantry',
#   'pantry'],
#  1553: ['dairy eggs',
#   'other',
#   'bakery',
#   'dairy eggs',
#   'produce',
#   'snacks',
#   'produce',
#   'produce',
#   'produce',
#   'produce'],
#  1555: ['produce',
#   'dairy eggs',
#   'dry goods pasta',
#   'produce',
#   'produce',
#   'dairy eggs',
#   'produce',
#   'international',
#   'canned goods',
#   'bakery',
#   'dairy eggs',
#   'produce',
#   'dairy eggs',
#   'produce'],
#  1556: ['produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'produce',
#   'canned goods',
#   'produce',
#   'snacks',
#   'pantry',
#   'dry goods pasta',
#   'canned goods',
#   'canned goods',
#   'meat seafood',
#   'breakfast',
#   'international',
#   'dairy eggs',
#   'dairy eggs',
#   'dairy eggs',
#   'deli'],
#  1557: ['beverages',
#   'snacks',
#   'snacks',
#   'pantry',
#   'dry goods pasta',
#   'beverages'],
#  1559: ['canned goods',
#   'canned goods',
#   'dairy eggs',
#   'dairy eggs',
#   'personal care',
#   'canned goods',
#   'canned goods',
#   'produce',
#   'produce'],
#  1562: ['produce',
#   'pantry',
#   'missing',
#   'pantry',
#   'deli',
#   'pantry',
#   'pantry',
#   'produce',
#   'beverages',
#   'produce',
#   'produce',
#   'deli',
#   'snacks',
#   'breakfast',
#   'pantry',
#   'breakfast',
#   'breakfast',
#   'meat seafood',
#   'produce',
#   'pantry',
#   'meat seafood'],
#  1565: ['meat seafood', 'meat seafood', 'frozen'],
#  1566: ['beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'beverages',
#   'snacks',
#   'snacks',
#   'snacks',
#   'dairy eggs',
#   'snacks',
#   'snacks',
#   'snacks',
#   'dairy eggs'],
#  ...}
